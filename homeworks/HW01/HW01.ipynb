# %%
import numpy as np

# %%
arr = np.array([1,23,2,23,23])
arr2 = np.ones(shape=[3,3])
arr3 = np.zeros(shape=[4,1])
arr4 = np.arange(0,21,3)

# %%
print(arr4, "\n", arr4.shape, arr4.dtype)
# Out:
# [ 0  3  6  9 12 15 18]
#  (7,) int64

# %%
print(arr4[1], arr4[::-1])
# Out:
# 3 [18 15 12  9  6  3  0]

# %%
arr1 = np.arange(0,7)
print(arr1*arr4, arr1+arr4)
print(arr.mean())
# Out:
# [  0   3  12  27  48  75 108] [ 0  4  8 12 16 20 24]
# 14.4
